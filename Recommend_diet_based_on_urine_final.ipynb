# %%
from sklearn.preprocessing import StandardScaler
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import mysql.connector
import pandas as pd

import json

with open('config.json') as f:
    config = json.load(f)


cnx = mysql.connector.connect(user=config['user'],
                              password=config['password'],
                              host=config['host'],
                              database=config['database'])

cursor = cnx.cursor()

# Example query
query = ("SELECT * FROM PH_Temp_Diet")

cursor.execute(query)

# Fetch the rows
rows = cursor.fetchall()

# Create a pandas DataFrame
data = pd.DataFrame(rows, columns=[desc[0] for desc in cursor.description])


cursor.close()
cnx.close()

# %%
df3 =data
df3 = df3.drop(['id'], axis=1)

# Pivot the data to create columns for each unique food_name
pivoted_data = df3.pivot_table(index=['person_id', 'date','PH','temperature'], columns='food_name', values='amount')

# Rename columns to remove the 'food_name' label prefix
pivoted_data.columns.name = None
# Set all non-zero amounts to 1
pivoted_data = pivoted_data.applymap(lambda x: 1 if x > 0 else 0)

pivoted_data.columns = pivoted_data.columns.str.replace('food_name_', '')

# # Join the pivoted data with the original data on the 'person_id' and 'date' columns
joined_data = pd.merge(data.drop(columns=['food_name', 'amount','id']), pivoted_data, on=['person_id', 'date','temperature','PH'])

# # Save the joined data to a new CSV file
#df3 = pivoted_data
# Group by 'person_id' and 'date', and aggregate the other columns
grouped_df = joined_data.groupby(['person_id', 'date','temperature','PH'], as_index=False);
joined_data = joined_data.drop_duplicates()
joined_data
# Out:
#          PH  temperature        date  person_id  Apple  Apple Pie  Banana  \
# 0      5.40         35.8  2017-09-06          1      0          0       1
# 97     7.50         36.1  2017-09-07          1      0          0       0
# 190    5.81         36.4  2017-09-08          1      0          0       0
# 283    7.50         36.6  2017-09-09          1      0          0       1
# 376    7.50         35.9  2017-09-10          1      0          0       1
# ...     ...          ...         ...        ...    ...        ...     ...
# 19348  5.37         36.1  2018-04-02          1      1          0       0
# 19441  5.82         36.5  2018-04-03          1      1          0       1
# 19534  5.03         36.1  2018-04-04          1      1          0       0
# 19627  6.00         36.3  2018-04-05          1      0          0       0
# 19720  5.40         35.8  2017-09-06          2      0          0       0
#
#        Beer  Braised Potatoes  Bread  ...  Tangerines  Tea(black/green)  \
# 0         0                 0      0  ...           0                 0
# 97        0                 0      1  ...           0                 0
# 190       0                 0      1  ...           0                 0
# 283       1                 0      1  ...           0                 0
# 376       0                 0      1  ...           0                 0
# ...     ...               ...    ...  ...         ...               ...
# 19348     0                 0      1  ...           0                 0
# 19441     0                 0      1  ...           0                 0
# 19534     0                 0      1  ...           0                 0
# 19627     0                 0      1  ...           0                 1
# 19720     0                 0      0  ...           0                 0
#
#        Tequila  The nuts  The vinaigrette  Vegetable salad  Water  Watermelon  \
# 0            0         1                0                0      1           0
# 97           0         1                0                0      1           0
# 190          0         1                0                0      0           0
# 283          0         1                0                0      1           0
# 376          0         1                0                0      1           0
# ...        ...       ...              ...              ...    ...         ...
# 19348        0         0                0                1      1           0
# 19441        0         0                0                1      1           0
# 19534        0         0                0                0      1           0
# 19627        0         1                0                0      1           0
# 19720        0         0                0                0      0           0
#
#        White wine  Zucchini Fritters
# 0               0                  1
# 97              0                  1
# 190             0                  1
# 283             0                  0
# 376             0                  0
# ...           ...                ...
# 19348           0                  0
# 19441           0                  0
# 19534           0                  0
# 19627           0                  0
# 19720           0                  0
#
# [213 rows x 97 columns]

# %%
from sklearn.model_selection import train_test_split

X= joined_data.iloc[:,0:1]
X
# Out:
#          PH
# 0      5.40
# 97     7.50
# 190    5.81
# 283    7.50
# 376    7.50
# ...     ...
# 19348  5.37
# 19441  5.82
# 19534  5.03
# 19627  6.00
# 19720  5.40
#
# [213 rows x 1 columns]

# %%
y = joined_data.iloc[:,5:]
y
# Out:
#        Apple Pie  Banana  Beer  Braised Potatoes  Bread  Buckwheat porridge  \
# 0              0       1     0                 0      0                   0
# 97             0       0     0                 0      1                   0
# 190            0       0     0                 0      1                   0
# 283            0       1     1                 0      1                   0
# 376            0       1     0                 0      1                   0
# ...          ...     ...   ...               ...    ...                 ...
# 19348          0       0     0                 0      1                   0
# 19441          0       1     0                 0      1                   0
# 19534          0       0     0                 0      1                   0
# 19627          0       0     0                 0      1                   0
# 19720          0       0     0                 0      0                   0
#
#        Bun  Cake  Candies  Cheese  ...  Tangerines  Tea(black/green)  Tequila  \
# 0        0     0        0       0  ...           0                 0        0
# 97       0     0        0       0  ...           0                 0        0
# 190      0     0        0       0  ...           0                 0        0
# 283      0     0        0       0  ...           0                 0        0
# 376      1     0        0       0  ...           0                 0        0
# ...    ...   ...      ...     ...  ...         ...               ...      ...
# 19348    0     0        0       0  ...           0                 0        0
# 19441    0     0        0       0  ...           0                 0        0
# 19534    0     1        0       1  ...           0                 0        0
# 19627    0     1        0       1  ...           0                 1        0
# 19720    0     0        0       0  ...           0                 0        0
#
#        The nuts  The vinaigrette  Vegetable salad  Water  Watermelon  \
# 0             1                0                0      1           0
# 97            1                0                0      1           0
# 190           1                0                0      0           0
# 283           1                0                0      1           0
# 376           1                0                0      1           0
# ...         ...              ...              ...    ...         ...
# 19348         0                0                1      1           0
# 19441         0                0                1      1           0
# 19534         0                0                0      1           0
# 19627         1                0                0      1           0
# 19720         0                0                0      0           0
#
#        White wine  Zucchini Fritters
# 0               0                  1
# 97              0                  1
# 190             0                  1
# 283             0                  0
# 376             0                  0
# ...           ...                ...
# 19348           0                  0
# 19441           0                  0
# 19534           0                  0
# 19627           0                  0
# 19720           0                  0
#
# [213 rows x 92 columns]

# %%
y = data.groupby(['person_id', 'date'])[['food_name', 'amount']].agg(list)
# Reset the index
y = y.reset_index()

# Custom function to combine food_name and amount into one list
def combine_food_and_amount(food_names, amounts):
    combined = []
    for food, amount in zip(food_names, amounts):
        if amount != 0:
            amount = 1
        combined.append((food, amount))
    return combined

# Apply the custom function to combine food_name and amount columns
y['food_and_amount'] = y.apply(lambda row: combine_food_and_amount(row['food_name'], row['amount']), axis=1)

# Drop the food_name and amount columns
y = y.drop(['food_name', 'amount','person_id','date'], axis=1)

# Print the modified DataFrame
print(y.head(5))
# Out:
#                                      food_and_amount
# 0  [(Gym, 0.0), (Liquid, 1), (Lemon water, 1), (T...
# 1  [(Gym, 1), (Liquid, 1), (Lemon water, 1), (Tea...
# 2  [(Gym, 0.0), (Liquid, 1), (Lemon water, 1), (T...
# 3  [(Gym, 0.0), (Liquid, 1), (Lemon water, 1), (T...
# 4  [(Gym, 1), (Liquid, 1), (Lemon water, 1), (Tea...

# %%
df = pd.DataFrame(y)
df2 = pd.DataFrame(X)
# convert column 'A' to a tuple
food_and_amount = tuple(df['food_and_amount'].tolist())
ph = tuple(df2['PH'].tolist())
print(ph)
# Out:
# (5.4, 7.5, 5.81, 7.5, 7.5, 5.67, 7.5, 5.81, 6.0, 7.5, 7.5, 5.94, 7.5, 7.5, 7.5, 7.5, 7.5, 5.48, 7.5, 5.6, 7.5, 7.5, 7.5, 5.87, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 5.97, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 7.5, 5.99, 5.63, 5.65, 7.5, 5.97, 4.98, 5.14, 7.5, 7.5, 5.35, 7.5, 5.86, 5.69, 5.31, 5.43, 5.12, 5.85, 5.95, 7.5, 5.96, 5.64, 7.5, 5.68, 5.73, 7.5, 5.97, 5.94, 5.99, 7.5, 5.52, 5.68, 7.5, 5.88, 7.5, 5.47, 5.72, 4.96, 5.67, 7.5, 7.5, 7.5, 5.95, 7.5, 7.5, 5.95, 7.5, 5.51, 5.38, 5.34, 5.71, 7.5, 5.57, 5.02, 5.47, 5.24, 7.5, 5.57, 7.5, 5.79, 5.5, 7.5, 5.99, 5.56, 5.38, 5.59, 5.46, 7.5, 5.07, 5.77, 5.87, 7.5, 7.5, 5.54, 5.89, 5.6, 5.97, 7.5, 7.5, 7.5, 7.5, 7.5, 5.77, 7.5, 7.5, 7.5, 7.5, 5.99, 7.5, 5.98, 7.5, 5.81, 7.5, 7.5, 7.5, 7.5, 7.5, 5.81, 5.77, 7.5, 7.5, 7.5, 6.0, 5.86, 7.5, 5.89, 7.5, 5.84, 7.5, 7.5, 5.74, 5.69, 5.35, 5.59, 5.77, 5.54, 5.39, 5.33, 5.52, 7.5, 7.5, 5.81, 5.73, 5.59, 5.13, 5.69, 5.5, 5.61, 5.4, 5.05, 4.84, 5.4, 5.14, 5.06, 5.69, 5.35, 4.95, 4.75, 5.24, 5.34, 5.65, 5.49, 5.75, 5.37, 5.82, 5.03, 6.0, 5.4)

# %%
food_and_amount
# Out:
# ([('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 0.0),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 1),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 1),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0),
#   ('Gym', 0.0),
#   ('Gym', 0.0),
#   ('Gym', 0.0),
#   ('Gym', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 1),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 1),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 1),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 1),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 0.0),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 1),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 1),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 1),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 1),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 1),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 1),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 1),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 1),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 1),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 1),
#   ('Oatmeal', 0.0),
#   ('Pizza with meat', 1),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 1),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 1),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 0.0),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 1),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 1),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 1),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 1),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 1),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 1),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 1),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 1),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 1),
#   ('Watermelon', 1),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 1),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 1),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 1),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 1),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 1),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 0.0),
#   ('Tea(black/green)', 1),
#   ('Fruit tea', 0.0),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 1),
#   ('Oatmeal', 0.0),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 1),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 1),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 1),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 1),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 0.0),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 1),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 0.0),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 1),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 1),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 1),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 0.0),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 1),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 1),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 1),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 0.0),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 1),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 1),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 1),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 1),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 1),
#   ('Fruit tea', 1),
#   ('Water', 0.0),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 1),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 0.0),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 1),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 0.0),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 1),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 1),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 1),
#   ('Cake', 1),
#   ('Bun', 0.0),
#   ('Croissant', 1),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 1),
#   ('Oatmeal', 0.0),
#   ('Pizza with meat', 1),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 0.0),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 1),
#   ('Bun', 0.0),
#   ('Croissant', 1),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 1),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 1),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 1),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 0.0),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 1),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 0.0),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 1),
#   ('Zucchini Fritters', 1),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 1),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 1),
#   ('Plum', 1),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 0.0),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 0.0),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
# ...
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 1),
#   ('Apple Pie', 1),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 1),
#   ('Cake', 1),
#   ('Bun', 1),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 1),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 1),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 1),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 1),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 0.0),
#   ('Cake', 1),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 1),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 1),
#   ('Fruit tea', 0.0),
#   ('Water', 1),
#   ('Latte', 1),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 1),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 0.0),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 1),
#   ('Curd', 1),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 1),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 1),
#   ('Raisins', 0.0),
#   ('Dried apricots', 0.0),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 1),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 1),
#   ('Fruit tea', 0.0),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 1),
#   ('Oatmeal', 0.0),
#   ('Pizza with meat', 1),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 1),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 1),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 1),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 1),
#   ('Cake', 1),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 1),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 1),
#   ('Mineral water (Esentuki - 4)', 1),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 1),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 1),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 1),
#   ('Cookie', 1),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 0.0),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 0.0),
#   ('Curd', 1),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 1),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 0.0),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 1),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 1),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 1),
#   ('Cake', 0.0),
#   ('Bun', 0.0),
#   ('Croissant', 1),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 1),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 0.0),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 1),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 1),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 0.0),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 1),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 1),
#   ('Curd', 1),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 1),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 0.0),
#   ('Pumpkin seeds', 1),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 1),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 1),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 1),
#   ('Cake', 1),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 1),
#   ('Liquid', 1),
#   ('Lemon water', 1),
#   ('Tea(black/green)', 1),
#   ('Fruit tea', 1),
#   ('Water', 1),
#   ('Latte', 0.0),
#   ('Mineral water (Esentuki - 4)', 0.0),
#   ('Mineral water (Borjomi)', 0.0),
#   ('Mineral water (Prolom)', 1),
#   ('Tequila', 0.0),
#   ('Red wine', 0.0),
#   ('White wine', 0.0),
#   ('Strong alcohol', 0.0),
#   ('Beer', 0.0),
#   ('Morse', 0.0),
#   ('Milk', 1),
#   ('Orange juice', 0.0),
#   ('Oatmeal', 1),
#   ('Pizza with meat', 1),
#   ('Cheese Pizza', 0.0),
#   ('Cheesecakes', 0.0),
#   ('Scrambled eggs', 0.0),
#   ('Mayonnaise salad', 0.0),
#   ('Bread', 1),
#   ('Meat', 0.0),
#   ('Sauce', 0.0),
#   ('Cutlet', 0.0),
#   ('Sausage', 0.0),
#   ('Fish', 0.0),
#   ('Sushi', 0.0),
#   ('Cod liver', 0.0),
#   ('Cheese', 1),
#   ('Curd', 0.0),
#   ('Sour cream', 0.0),
#   ('Buckwheat porridge', 0.0),
#   ('Noodles with vegetables', 0.0),
#   ('Noodles with shrimp', 0.0),
#   ('Meat pilaf', 0.0),
#   ('Meatless pilaf', 0.0),
#   ('Pea soup with meat', 0.0),
#   ('Fried vegetables', 0.0),
#   ('Pyagse with vegetables', 0.0),
#   ('Dumplings with cabbage', 0.0),
#   ('Potato dumplings', 0.0),
#   ('Zucchini Fritters', 0.0),
#   ('Stewed cabbage', 0.0),
#   ('Solyanka with meat', 0.0),
#   ('Eggplant with cheese', 0.0),
#   ('Pasta', 0.0),
#   ('Fried potatoes', 0.0),
#   ('Cooked Potatoes', 0.0),
#   ('Braised Potatoes', 0.0),
#   ('Mashed potatoes', 0.0),
#   ('Apple Pie', 0.0),
#   ('Patty with cabbage', 0.0),
#   ('Curd Pie', 0.0),
#   ('Cheese Pie', 0.0),
#   ('Egg Pie', 0.0),
#   ('Potato pie', 0.0),
#   ('Meat pie', 0.0),
#   ('Khachapuri', 0.0),
#   ('The nuts', 1),
#   ('Pumpkin seeds', 1),
#   ('Raisins', 0.0),
#   ('Dried apricots', 1),
#   ('Vegetable salad', 0.0),
#   ('Eggplant caviar', 0.0),
#   ('The vinaigrette', 0.0),
#   ('Apple', 0.0),
#   ('Peach', 0.0),
#   ('Melon', 0.0),
#   ('Plum', 0.0),
#   ('Tangerines', 0.0),
#   ('Pear', 0.0),
#   ('Watermelon', 0.0),
#   ('Banana', 0.0),
#   ('Grapes', 0.0),
#   ('Pineapple', 0.0),
#   ('Orange', 0.0),
#   ('Paste', 0.0),
#   ('Kumquat', 0.0),
#   ('Ice cream', 0.0),
#   ('Cookie', 1),
#   ('Cake', 1),
#   ('Bun', 0.0),
#   ('Croissant', 0.0),
#   ('Chocolate', 0.0),
#   ('Candies', 0.0),
#   ('Halva', 0.0),
#   ('Marshmallow', 0.0),
#   ('Red caviar', 0.0),
#   ('Jelly', 0.0)],
#  [('Gym', 0.0)])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

data = pd.DataFrame({
    'pH_level': ph,
    'food_and_activities': food_and_amount
})

def categorize_pH(pH):
    if pH < 7.0:
        return "acidic"
    elif pH > 7.0:
        return "alkaline"
    else:
        return "neutral"

data['pH_category'] = data['pH_level'].apply(categorize_pH)

def binary_representation(row):
    binary_list = [row['pH_category']]
    for food, amount in row['food_and_activities']:
        if amount > 0:
            binary_list.append(food)
    return binary_list

data['binary'] = data.apply(binary_representation, axis=1)

transactions = data['binary'].tolist()

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
binary_df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(binary_df, min_support=0.1, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.01)

# Filter the rules based on the antecedent (left-hand side) containing the pH category "acidic"
acidic_rules = rules[rules['antecedents'].apply(lambda x: 'acidic' in x)]
alkaline_rules = rules[rules['antecedents'].apply(lambda x: 'alkaline' in x)]

print(alkaline_rules)
# Out:
#                    antecedents  \
# 53                  (alkaline)
# 87                  (alkaline)
# 140                 (alkaline)
# 259                 (alkaline)
# 326                 (alkaline)
# ...                        ...
# 1281679      (alkaline, Water)
# 1281682  (alkaline, Fruit tea)
# 1281684    (Oatmeal, alkaline)
# 1281686   (alkaline, Red wine)
# 1281694             (alkaline)
#
#                                                consequents  \
# 53                                                 (Apple)
# 87                                                (Banana)
# 140                                                (Bread)
# 259                                               (Cookie)
# 326                                       (Dried apricots)
# ...                                                    ...
# 1281679  (The nuts, Liquid, Mineral water (Esentuki - 4...
# 1281682  (The nuts, Liquid, Mineral water (Esentuki - 4...
# 1281684  (The nuts, Liquid, Mineral water (Esentuki - 4...
# 1281686  (The nuts, Liquid, Mineral water (Esentuki - 4...
# 1281694  (The nuts, Liquid, Mineral water (Esentuki - 4...
#
#          antecedent support  consequent support   support  confidence  \
# 53                 0.488263            0.661972  0.276995    0.567308
# 87                 0.488263            0.272300  0.169014    0.346154
# 140                0.488263            0.737089  0.352113    0.721154
# 259                0.488263            0.586854  0.253521    0.519231
# 326                0.488263            0.582160  0.267606    0.548077
# ...                     ...                 ...       ...         ...
# 1281679            0.370892            0.262911  0.103286    0.278481
# 1281682            0.488263            0.197183  0.103286    0.211538
# 1281684            0.361502            0.230047  0.103286    0.285714
# 1281686            0.262911            0.267606  0.103286    0.392857
# 1281694            0.488263            0.192488  0.103286    0.211538
#
#              lift  leverage  conviction
# 53       0.856997 -0.046221    0.781221
# 87       1.271220  0.036060    1.112952
# 140      0.978381 -0.007781    0.942853
# 259      0.884769 -0.033018    0.859343
# 326      0.941455 -0.016641    0.924583
# ...           ...       ...         ...
# 1281679  1.059222  0.005775    1.021580
# 1281682  1.072802  0.007009    1.018207
# 1281684  1.241983  0.020124    1.077934
# 1281686  1.468045  0.032930    1.206297
# 1281694  1.098968  0.009302    1.024161
#
# [84857 rows x 9 columns]

# %%
def recommend_food_and_activities(pH_level, rules):
    pH_category = categorize_pH(pH_level)

    # Filter the rules based on the antecedent (left-hand side) containing the pH category
    recommendations = rules[rules['antecedents'].apply(lambda x: pH_category in x)]

    # Sort the rules by confidence and select the top 5 rules
    top_recommendations = recommendations.sort_values(by='confidence', ascending=False).head(5)

    # Extract the consequents (right-hand side) of the rules
    recommended_items = set()
    for _, row in top_recommendations.iterrows():
        recommended_items.update(row['consequents'])

    # Remove the pH category from the recommended items
    recommended_items.discard(pH_category)

    return list(recommended_items)

# %%
# Example usage
urine_pH = 9 # Replace this with the actual pH level data from the sensor
recommended_items = recommend_food_and_activities(urine_pH, alkaline_rules)
print("Recommended food and activities:", recommended_items)
# Out:
# Recommended food and activities: ['Liquid', 'Lemon water', 'Fruit tea']

# %%
import joblib

# Save the association rules DataFrame to a file
joblib.dump(alkaline_rules, 'alkaline_rules.joblib')
# Out:
# ['alkaline_rules.joblib']
